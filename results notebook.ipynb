# %%
import pandas as pd
import numpy as np
import os

from preprocessing import preprocess, full_data_preprocess
from thesismodels import models

# %%
L87dat = preprocess(path = './nnsamL78', save_dir='./L8resdat/', X=['L8', 'SA', 'SE'], Y = 'L7')
L87dat.get_df()
L87dat.pre_process()
L87dat.get_data_with_plot(X='L8')

x1, x2, y1, y2 = L87dat.output()
# Out:
# 21963
#               index            L8            SA            SE            L7
# count  21963.000000  21963.000000  21963.000000  21963.000000  21963.000000
# mean     845.624915  14476.865956     34.539225     27.683230  14198.042594
# std      628.441858   3726.616355      1.422866      6.245212   3507.456511
# min        0.000000   2142.000000     32.961056     14.101892   7004.000000
# 25%      343.000000  12505.500000     33.400497     22.792894  12314.000000
# 50%      715.000000  14239.000000     33.984825     28.611979  13964.000000
# 75%     1239.000000  16451.500000     35.367737     32.620865  15940.500000
# max     2920.000000  60060.000000     40.000510     41.653520  65535.000000
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
L87models = models(x1,x2,y1,y2, xplotname='L8', save_dir='./L8resdat/')
L87models.benchmarreg(print_process = True, plot = True)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                          1.159e+06
# Date:                Sat, 24 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:04:36   Log-Likelihood:                     -1.5630e+05
# No. Observations:               17558   AIC:                                  3.126e+05
# Df Residuals:                   17557   BIC:                                  3.126e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
L87models.polyreg(maxit = 15, print_process = True, plot = True)
# Out:
# poly = 0, RMSE_train = 3237.480984150923, RMSE_test = 3331.4354458665084
# poly = 1, RMSE_train = 1600.9305804834112, RMSE_test = 1657.9085971432862
# poly = 2, RMSE_train = 1563.5277874805377, RMSE_test = 1636.344130424353
# poly = 3, RMSE_train = 1554.0037265496317, RMSE_test = 1633.1000066800993
# poly = 4, RMSE_train = 1547.821140292814, RMSE_test = 1637.1281387208548
# poly = 5, RMSE_train = 1547.36771455646, RMSE_test = 1652.1908289678972
# poly = 6, RMSE_train = 1551.6946317611937, RMSE_test = 1645.9695703221666
# poly = 7, RMSE_train = 1561.3355413176848, RMSE_test = 1660.7800144719188
# poly = 8, RMSE_train = 1638.5621952590307, RMSE_test = 1762.816762511343
# poly = 9, RMSE_train = 1841.6285096008864, RMSE_test = 1877.9583481096445
# poly = 10, RMSE_train = 1972.5607309279496, RMSE_test = 3148.721902945168
# poly = 11, RMSE_train = 2685.373428730538, RMSE_test = 2499.5832890474685
# poly = 12, RMSE_train = 3695.5919585157535, RMSE_test = 3372.4646471983174
# ...

# %%
L87models.NNmodel(maxit = 500,print_process = True, plot = True)
# Out:
# [[14480.868       34.544407    27.718441]]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  normalization_1 (Normalizat  (None, 3)                7
#  ion)
#
#  dense_1 (Dense)             (None, 1)                 4
#
# ...
# Total params: 11
# Trainable params: 4
# Non-trainable params: 7
# _________________________________________________________________
# None
# Epoch 1/500
# 439/439 [==============================] - 1s 1ms/step - loss: 14522.3877 - rmse: 14522.4443 - val_loss: 14420.4902 - val_rmse: 14420.7314
# Epoch 2/500
# 439/439 [==============================] - 1s 1ms/step - loss: 14475.3789 - rmse: 14475.3818 - val_loss: 14371.9590 - val_rmse: 14372.1865
# Epoch 3/500
# 439/439 [==============================] - 1s 1ms/step - loss: 14425.2109 - rmse: 14425.1934 - val_loss: 14323.4658 - val_rmse: 14323.6787
# Epoch 4/500
# ...

# %%
L87models.summary()
# Out:
# {'Benchmark only Landsat RMSE': 1801.9509996636884, 'Benchmark OLS Regression RMSE': 1659.32064145703, 'Polynomial model RMSE': 1632.7959445550885, 'Neural Network model RMSE': 1263.7064208984375}

# %% [markdown]
# ### L5 to L7

# %%
L57dat = preprocess(path = './nssamL57', save_dir='./L5resdat/', X=['L5', 'SA', 'SE'], Y = 'L7')
L57dat.get_df()
L57dat.pre_process()
L57dat.get_data_with_plot(X='L5')

x1, x2, y1, y2 = L57dat.output()

L57models = models(x1,x2,y1,y2, xplotname='L5', save_dir='./L5resdat/')
# Out:
# 8381
#              index            L5           SA           SE            L7
# count  8381.000000   8381.000000  8381.000000  8381.000000   8381.000000
# mean   1034.143420  18315.984966    52.076281    39.472380  17881.809927
# std     999.357701   9798.425020     8.151574     9.272987  10419.042996
# min       0.000000   6624.000000    39.407340    14.911992   6207.000000
# 25%     244.000000  12881.000000    44.227245    31.805695  13200.000000
# 50%     671.000000  14698.000000    52.537968    39.549560  14794.000000
# 75%    1518.000000  18396.000000    56.213253    46.053150  17246.000000
# max    3613.000000  65535.000000    75.521930    57.862835  65535.000000
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
L57models.benchmarreg()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared (uncentered):                   0.874
# Model:                            OLS   Adj. R-squared (uncentered):              0.874
# Method:                 Least Squares   F-statistic:                          4.492e+04
# Date:                Sat, 24 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        13:18:37   Log-Likelihood:                         -65591.
# No. Observations:                6458   AIC:                                  1.312e+05
# Df Residuals:                    6457   BIC:                                  1.312e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
L57models.polyreg(maxit = 15, print_process = True, plot = True)
# Out:
# poly = 0, RMSE_train = 6472.485985373205, RMSE_test = 6476.321181115989
# poly = 1, RMSE_train = 5102.753696523195, RMSE_test = 5166.521051078901
# poly = 2, RMSE_train = 4570.3049611139695, RMSE_test = 4612.000178619161
# poly = 3, RMSE_train = 4206.309242114672, RMSE_test = 4137.493351926059
# poly = 4, RMSE_train = 7458.176129714716, RMSE_test = 7545.894383066135
# poly = 5, RMSE_train = 4466.963592013505, RMSE_test = 4493.795302143866
# poly = 6, RMSE_train = 4117.612227068417, RMSE_test = 4053.5183660590537
# poly = 7, RMSE_train = 4135.960342588092, RMSE_test = 4111.187545786148
# poly = 8, RMSE_train = 4268.0712618432135, RMSE_test = 5318.975807655074
# poly = 9, RMSE_train = 4345.930615677909, RMSE_test = 4403.9876287140705
# poly = 10, RMSE_train = 4326.280910780393, RMSE_test = 4501.967049811148
# poly = 11, RMSE_train = 4671.924767299623, RMSE_test = 7819.978267875041
# poly = 12, RMSE_train = 4726.83510332011, RMSE_test = 5435.319420807169
# ...

# %%
L57models.NNmodel(maxit = 1500,print_process = True, plot = True)
# Out:
# [[17593.623       51.927593    39.28564 ]]
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  normalization_3 (Normalizat  (None, 3)                7
#  ion)
#
#  dense_3 (Dense)             (None, 1)                 4
#
# ...
# Total params: 11
# Trainable params: 4
# Non-trainable params: 7
# _________________________________________________________________
# None
# Epoch 1/1500
# 162/162 [==============================] - 1s 2ms/step - loss: 17432.8711 - rmse: 17427.9375 - val_loss: 17738.2012 - val_rmse: 17677.5352
# Epoch 2/1500
# 162/162 [==============================] - 0s 1ms/step - loss: 17413.9531 - rmse: 17405.3984 - val_loss: 17720.3711 - val_rmse: 17659.7988
# Epoch 3/1500
# 162/162 [==============================] - 0s 1ms/step - loss: 17397.8809 - rmse: 17392.7324 - val_loss: 17702.4512 - val_rmse: 17641.9766
# Epoch 4/1500
# ...

# %%
L57models.summary()
# Out:
# {'Benchmark only Landsat RMSE': 6347.9770269997825, 'Benchmark OLS Regression RMSE': 5344.14215922509, 'Polynomial model RMSE': 4609.041290734638, 'Neural Network model RMSE': 4057.781494140625}

# %% [markdown]
# ## L8 and 7 with spatial dependency

# %%
L87fulldat = full_data_preprocess(path = r"C:\Users\Jurrian\Thesisdata\full_data\csv_nssam_3days_L7and8_full_2015-06-02.csv", save_dir= './L87fulldat/',
                                  X = ['L8', 'SA', 'SE'], Y = 'L7') 
L87fulldat.plot_data()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
L87fulldat.process_data()
x1, y1 = L87fulldat.output()

L87fulldat_test = full_data_preprocess(path = r"C:\Users\Jurrian\Thesisdata\full_data\csv_nssam_3days_L7and8_full_2015-04-01_psnw.csv", save_dir= './L87fulldattest/',
                                  X = ['L8', 'SA', 'SE'], Y = 'L7') 
L87fulldat_test.plot_data()
L87fulldat_test.process_data()
x2, y2 = L87fulldat_test.output()
# Out:
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat[self.Y] = self.df[self.Y]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat[self.Y] = self.df[self.Y]

# %%
L87fulldatmodels = models(x1,x2,y1, y2, save_dir= './L87fulldat/', xplotname='L8')
L87fulldatmodels.benchmarreg()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.993
# Method:                 Least Squares   F-statistic:                          1.764e+09
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):                        0.00
# Time:                        12:19:51   Log-Likelihood:                     -9.9848e+07
# No. Observations:            11728517   AIC:                                  1.997e+08
# Df Residuals:                11728516   BIC:                                  1.997e+08
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
L87fulldatmodels.polyreg(maxit = 3, print_process = True, plot = True)
# Out:
# poly = 0, RMSE_train = 2342.552811029791, RMSE_test = 3939.5960603785575
# poly = 1, RMSE_train = 1134.9192748910957, RMSE_test = 474687.19361656654
# poly = 2, RMSE_train = 1108.2462793100044, RMSE_test = 48217086.92868242
# poly = 3, RMSE_train = 1106.7205788835881, RMSE_test = 707345631.8799596
# Best poly = 0
#                             OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):                nan
# Time:                        12:21:20   Log-Likelihood:            -1.0764e+08
# No. Observations:            11728517   AIC:                         2.153e+08
# Df Residuals:                11728516   BIC:                         2.153e+08
# Df Model:                           0
# ...

# %%
L87fulldatmodels.NNmodel(maxit = 3,print_process = True, plot = True)
# Out:
# [[15282.672       33.554047    28.477623]]
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  normalization_2 (Normalizat  (None, 3)                7
#  ion)
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 11
# Trainable params: 4
# Non-trainable params: 7
# _________________________________________________________________
# None
# Epoch 1/3
# 293213/293213 [==============================] - 266s 905us/step - loss: 4162.5874 - rmse: 4162.5864 - val_loss: 832.1074 - val_rmse: 832.1005
# Epoch 2/3
# 293213/293213 [==============================] - 258s 881us/step - loss: 1128.7548 - rmse: 1128.7548 - val_loss: 856.5781 - val_rmse: 856.5712
# Epoch 3/3
# ...
# 147720/147720 [==============================] - 94s 633us/step
# test results:
# {'loss': 107290.1953125, 'rmse': 107290.1953125}
#
# kernel weigts:
# ...

# %%
L87fulldatmodels.summary()
# Out:
# {'Benchmark only Landsat RMSE': 2763.169396934685, 'Benchmark OLS Regression RMSE': 12752.47622146504, 'Polynomial model RMSE': 3939.596060378627, 'Neural Network model RMSE': 107290.1953125}

# %% [markdown]
# ### L57

# %%
L57fulldat = full_data_preprocess(path = r"C:\Users\Jurrian\Thesisdata\full_data\csv_nssam_3weeks_6dayO_2000_L5and7_NIR_full_2003-12-11.csv", save_dir= './L57fulldat/',
                                  X = ['L5', 'SA', 'SE'], Y = 'L7') 
L57fulldat.plot_data(X='L5')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
L57fulldat.process_data()
x1, y1 = L57fulldat.output()

L57fulldat_test = full_data_preprocess(path = r"C:\Users\Jurrian\Thesisdata\full_data\csv_nssam_2weeks_6dayO_2000_L5and7_NIR_full_2000-10-03.csv", save_dir= './L57fulldattest/',
                                  X = ['L5', 'SA', 'SE'], Y = 'L7') 
L57fulldat_test.plot_data(X='L5', title='Comparrisson Plot testdata')
L57fulldat_test.process_data()
x2, y2 = L57fulldat_test.output()
# Out:
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat[self.Y] = self.df[self.Y]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\Users\Jurrian\OneDrive\Studie\Master\Thesis\adsThesis\preprocessing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat[self.Y] = self.df[self.Y]

# %%
L57fulldatmodels = models(x1,x2,y1, y2, save_dir= './L57fulldattest/', xplotname='L5')
L57fulldatmodels.benchmarreg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L57fulldatmodels = models(x1,x2,y1, y2, save_dir= './L57fulldattest/', xplotname='L5')
#       2 L57fulldatmodels.benchmarreg()
#
# NameError: name 'x1' is not defined

# %%
L57fulldatmodels.polyreg(maxit = 5, print_process = True, plot = True)
# Out:
# poly = 0, RMSE_train = 5873.802242045138, RMSE_test = 10579.748674604894
# poly = 1, RMSE_train = 5472.494897272348, RMSE_test = 84408.315174281
# poly = 2, RMSE_train = 5227.759611448572, RMSE_test = 9543521.339881321
# poly = 3, RMSE_train = 5204.106205045842, RMSE_test = 54356.65510076382
# poly = 4, RMSE_train = 5201.477334748991, RMSE_test = 106392.56186232778
# poly = 5, RMSE_train = 5201.417321617655, RMSE_test = 132444.1627951805
# Best poly = 0
#                             OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):                nan
# Time:                        16:47:59   Log-Likelihood:            -2.5255e+07
# No. Observations:             2501170   AIC:                         5.051e+07
# ...

# %%
L57fulldatmodels.bestpolymodel(1)
# Out:
# Best poly = 2
#                             OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                 1.901e+05
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:12:17   Log-Likelihood:            -2.5078e+07
# No. Observations:             2501170   AIC:                         5.016e+07
# Df Residuals:                 2501167   BIC:                         5.016e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 1              1.1500      0.000   2554.990      0.000       1.149       1.151
# ...

# %%
L57fulldatmodels.bestpolymodel(2)
# Out:
# Best poly = 2
#                             OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                 1.641e+05
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:07:58   Log-Likelihood:            -2.4963e+07
# No. Observations:             2501170   AIC:                         4.993e+07
# Df Residuals:                 2501165   BIC:                         4.993e+07
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 1              0.0002   3.35e-07    466.398      0.000       0.000       0.000
# ...

# %%
L57fulldatmodels.bestpolymodel(4)
# Out:
# Best poly = 2
#                             OLS Regression Results
# ...
# Dep. Variable:                     L7   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                 8.605e+04
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:10:43   Log-Likelihood:            -2.4951e+07
# No. Observations:             2501170   AIC:                         4.990e+07
# Df Residuals:                 2501161   BIC:                         4.990e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 1          -6.905e-11    9.6e-12     -7.193      0.000   -8.79e-11   -5.02e-11
# ...

# %%
L57fulldatmodels.NNmodel(maxit = 10,print_process = True, plot = True)
# Out:
# [[3.4981836e+04 1.5838531e+02 1.5965101e+01]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  normalization (Normalizatio  (None, 3)                7
#  n)
#
#  dense (Dense)               (None, 1)                 4
#
# ...
# Total params: 11
# Trainable params: 4
# Non-trainable params: 7
# _________________________________________________________________
# None
# Epoch 1/10
# 62530/62530 [==============================] - 54s 852us/step - loss: 25966.2891 - rmse: 25966.2461 - val_loss: 25663.4238 - val_rmse: 25663.0898
# Epoch 2/10
# 62530/62530 [==============================] - 53s 854us/step - loss: 19919.4863 - rmse: 19919.4492 - val_loss: 19026.8867 - val_rmse: 19026.5488
# Epoch 3/10
# 62530/62530 [==============================] - 54s 862us/step - loss: 14026.8789 - rmse: 14026.8721 - val_loss: 12378.9893 - val_rmse: 12378.6533
# Epoch 4/10
# ...

# %%
L57fulldatmodels.summary()
# Out:
# {'Benchmark only Landsat RMSE': 28244.101577219222, 'Benchmark OLS Regression RMSE': 79995.53384412431, 'Polynomial model RMSE': 10579.748674605085, 'Neural Network model RMSE': 584799.625}
